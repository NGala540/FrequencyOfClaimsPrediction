# %%
import pandas as pd
import csv
from io import StringIO

# %%
# Open the file and clean extra trailing commas
cleaned_lines = []
with open("modelowanie_pricing_EH.csv", "r") as f:
    for line in f:
        if len(line.split(",")) == 13:
            cleaned_lines.append(line)
        else:
            cleaned_lines.append(line.replace(",,",",").rstrip(",\n"))  # Remove trailing commas and newlines

# Convert cleaned data into a StringIO object for pandas
cleaned_csv = StringIO("\n".join(cleaned_lines))

# Read into pandas
df = pd.read_csv(cleaned_csv)

# %%
df
# Out:
#         Unnamed: 0      IDpol  ClaimNb  Exposure Area  VehPower  VehAge  \
# 0                0        1.0      1.0   0.10000    D       5.0     0.0
# 1                1        3.0      1.0   0.77000    D       5.0     0.0
# 2                2        5.0      1.0   0.75000    B       6.0     2.0
# 3                3       10.0      1.0   0.09000  NaN       7.0     0.0
# 4                4       11.0      1.0   0.84000    B       7.0     0.0
# ...            ...        ...      ...       ...  ...       ...     ...
# 678008      678008  6114326.0      0.0   0.00274    E       4.0     0.0
# 678009      678009  6114327.0      0.0   0.00274    E       4.0     0.0
# 678010      678010  6114328.0      0.0   0.00274    D       6.0     2.0
# 678011      678011  6114329.0      0.0   0.00274    B       4.0     0.0
# 678012      678012  6114330.0      0.0   0.00274    B       7.0     6.0
#
#         DrivAge  BonusMalus VehBrand   VehGas  Density Region
# 0          55.0        50.0      B12  Regular   1217.0    R82
# 1          55.0        50.0      B12  Regular   1217.0    R82
# 2          52.0        50.0      B12   Diesel     54.0    R22
# 3          46.0        50.0      B12   Diesel     76.0    R72
# 4          46.0        50.0      B12   Diesel     76.0    R72
# ...         ...         ...      ...      ...      ...    ...
# 678008     54.0        50.0      B12  Regular   3317.0    R93
# 678009     41.0        95.0      B12  Regular   9850.0    R11
# 678010     45.0        50.0      B12   Diesel   1323.0    R82
# 678011     60.0        50.0      B12  Regular     95.0    R26
# 678012     29.0        54.0      B12   Diesel     65.0    R72
#
# [678013 rows x 13 columns]
